# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.layers import Conv1D,MaxPool1D
from tensorflow.keras.optimizers import Adam

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
train_df = pd.read_csv('train_FD003.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])
train_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0005    0.0004     100.0  518.67  642.36  1583.23  1396.84
# 1   1      2    0.0008   -0.0003     100.0  518.67  642.50  1584.69  1396.89
# 2   1      3   -0.0014   -0.0002     100.0  518.67  642.18  1582.35  1405.61
# 3   1      4   -0.0020    0.0001     100.0  518.67  642.92  1585.61  1392.27
# 4   1      5    0.0016    0.0000     100.0  518.67  641.68  1588.63  1397.65
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  522.31  2388.01  8145.32  8.4246  0.03  391  2388  100.0
# 1  14.62  ...  522.42  2388.03  8152.85  8.4403  0.03  392  2388  100.0
# 2  14.62  ...  522.03  2388.00  8150.17  8.3901  0.03  391  2388  100.0
# 3  14.62  ...  522.49  2388.08  8146.56  8.3878  0.03  392  2388  100.0
# 4  14.62  ...  522.58  2388.03  8147.80  8.3869  0.03  392  2388  100.0
#
#      s20      s21
# 0  39.11  23.3537
# 1  38.99  23.4491
# 2  38.85  23.3669
# 3  38.96  23.2951
# 4  39.14  23.4583
#
# [5 rows x 26 columns]

# %%
test_df = pd.read_csv('test_FD003.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']
test_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0017   -0.0004     100.0  518.67  641.94  1581.93  1396.93
# 1   1      2    0.0006   -0.0002     100.0  518.67  642.02  1584.86  1398.90
# 2   1      3    0.0014   -0.0003     100.0  518.67  641.68  1581.78  1391.92
# 3   1      4    0.0027    0.0001     100.0  518.67  642.20  1584.53  1395.34
# 4   1      5   -0.0001    0.0001     100.0  518.67  642.46  1589.03  1395.86
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.89  2387.94  8133.48  8.3760  0.03  391  2388  100.0
# 1  14.62  ...  521.85  2388.01  8137.44  8.4062  0.03  391  2388  100.0
# 2  14.62  ...  522.10  2387.94  8138.25  8.3553  0.03  391  2388  100.0
# 3  14.62  ...  522.45  2387.96  8137.07  8.3709  0.03  392  2388  100.0
# 4  14.62  ...  521.91  2387.97  8134.20  8.4146  0.03  391  2388  100.0
#
#      s20      s21
# 0  39.07  23.4468
# 1  39.04  23.4807
# 2  39.10  23.4244
# 3  38.97  23.4782
# 4  39.09  23.3950
#
# [5 rows x 26 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16596 entries, 0 to 16595
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        16596 non-null  int64
#  1   cycle     16596 non-null  int64
#  2   setting1  16596 non-null  float64
#  3   setting2  16596 non-null  float64
#  4   setting3  16596 non-null  float64
#  5   s1        16596 non-null  float64
#  6   s2        16596 non-null  float64
#  7   s3        16596 non-null  float64
#  8   s4        16596 non-null  float64
#  9   s5        16596 non-null  float64
#  10  s6        16596 non-null  float64
#  11  s7        16596 non-null  float64
#  12  s8        16596 non-null  float64
#  13  s9        16596 non-null  float64
#  14  s10       16596 non-null  float64
#  15  s11       16596 non-null  float64
#  16  s12       16596 non-null  float64
#  17  s13       16596 non-null  float64
#  18  s14       16596 non-null  float64
#  19  s15       16596 non-null  float64
#  20  s16       16596 non-null  float64
#  21  s17       16596 non-null  int64
#  22  s18       16596 non-null  int64
#  23  s19       16596 non-null  float64
#  24  s20       16596 non-null  float64
#  25  s21       16596 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 3.3 MB

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24720 entries, 0 to 24719
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        24720 non-null  int64
#  1   cycle     24720 non-null  int64
#  2   setting1  24720 non-null  float64
#  3   setting2  24720 non-null  float64
#  4   setting3  24720 non-null  float64
#  5   s1        24720 non-null  float64
#  6   s2        24720 non-null  float64
#  7   s3        24720 non-null  float64
#  8   s4        24720 non-null  float64
#  9   s5        24720 non-null  float64
#  10  s6        24720 non-null  float64
#  11  s7        24720 non-null  float64
#  12  s8        24720 non-null  float64
#  13  s9        24720 non-null  float64
#  14  s10       24720 non-null  float64
#  15  s11       24720 non-null  float64
#  16  s12       24720 non-null  float64
#  17  s13       24720 non-null  float64
#  18  s14       24720 non-null  float64
#  19  s15       24720 non-null  float64
#  20  s16       24720 non-null  float64
#  21  s17       24720 non-null  int64
#  22  s18       24720 non-null  int64
#  23  s19       24720 non-null  float64
#  24  s20       24720 non-null  float64
#  25  s21       24720 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 5.1 MB

# %%
pm_truth=pd.read_csv('RUL_FD003.txt',sep=' ',header=None).drop([1],axis=1)
pm_truth.columns=['more']
pm_truth['id']=pm_truth.index+1
pm_truth.head()
# Out:
#    more  id
# 0    44   1
# 1    51   2
# 2    27   3
# 3   120   4
# 4   101   5

# %%
# generate column max for test data
# max = max no. of cycles that a engine has cmplted
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
rul.head()
# Out:
#    id  max
# 0   1  233
# 1   2  124
# 2   3  234
# 3   4   68
# 4   5  138

# %%
# run to failure = total cycles of a engine

pm_truth['rtf']=pm_truth['more']+rul['max']
pm_truth.head()
# Out:
#    more  id  rtf
# 0    44   1  277
# 1    51   2  175
# 2    27   3  261
# 3   120   4  188
# 4   101   5  239

# %%
pm_truth.drop('more', axis=1, inplace=True)
test_df=test_df.merge(pm_truth,on=['id'],how='left')
test_df['ttf']=test_df['rtf'] - test_df['cycle']

#ttf = true lifetime of a engine 

test_df.drop('rtf', axis=1, inplace=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0017   -0.0004     100.0  518.67  641.94  1581.93  1396.93
# 1   1      2    0.0006   -0.0002     100.0  518.67  642.02  1584.86  1398.90
# 2   1      3    0.0014   -0.0003     100.0  518.67  641.68  1581.78  1391.92
# 3   1      4    0.0027    0.0001     100.0  518.67  642.20  1584.53  1395.34
# 4   1      5   -0.0001    0.0001     100.0  518.67  642.46  1589.03  1395.86
#
#       s5  ...      s13      s14     s15   s16  s17   s18    s19    s20  \
# 0  14.62  ...  2387.94  8133.48  8.3760  0.03  391  2388  100.0  39.07
# 1  14.62  ...  2388.01  8137.44  8.4062  0.03  391  2388  100.0  39.04
# 2  14.62  ...  2387.94  8138.25  8.3553  0.03  391  2388  100.0  39.10
# 3  14.62  ...  2387.96  8137.07  8.3709  0.03  392  2388  100.0  38.97
# 4  14.62  ...  2387.97  8134.20  8.4146  0.03  391  2388  100.0  39.09
#
#        s21  ttf
# 0  23.4468  276
# 1  23.4807  275
# 2  23.4244  274
# 3  23.4782  273
# 4  23.3950  272
#
# [5 rows x 27 columns]

# %%
train_df['ttf'] = train_df.groupby(['id'])['cycle'].transform(max)-train_df['cycle']
train_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0005    0.0004     100.0  518.67  642.36  1583.23  1396.84
# 1   1      2    0.0008   -0.0003     100.0  518.67  642.50  1584.69  1396.89
# 2   1      3   -0.0014   -0.0002     100.0  518.67  642.18  1582.35  1405.61
# 3   1      4   -0.0020    0.0001     100.0  518.67  642.92  1585.61  1392.27
# 4   1      5    0.0016    0.0000     100.0  518.67  641.68  1588.63  1397.65
#
#       s5  ...      s13      s14     s15   s16  s17   s18    s19    s20  \
# 0  14.62  ...  2388.01  8145.32  8.4246  0.03  391  2388  100.0  39.11
# 1  14.62  ...  2388.03  8152.85  8.4403  0.03  392  2388  100.0  38.99
# 2  14.62  ...  2388.00  8150.17  8.3901  0.03  391  2388  100.0  38.85
# 3  14.62  ...  2388.08  8146.56  8.3878  0.03  392  2388  100.0  38.96
# 4  14.62  ...  2388.03  8147.80  8.3869  0.03  392  2388  100.0  39.14
#
#        s21  ttf
# 0  23.3537  258
# 1  23.4491  257
# 2  23.3669  256
# 3  23.2951  255
# 4  23.4583  254
#
# [5 rows x 27 columns]

# %%
df_train=train_df.copy()
df_test=test_df.copy()
period=30
df_train['label_bc'] = df_train['ttf'].apply(lambda x: 1 if x <= period else 0)
df_test['label_bc'] = df_test['ttf'].apply(lambda x: 1 if x <= period else 0)
df_train
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0005    0.0004     100.0  518.67  642.36  1583.23
# 1        1      2    0.0008   -0.0003     100.0  518.67  642.50  1584.69
# 2        1      3   -0.0014   -0.0002     100.0  518.67  642.18  1582.35
# 3        1      4   -0.0020    0.0001     100.0  518.67  642.92  1585.61
# 4        1      5    0.0016    0.0000     100.0  518.67  641.68  1588.63
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 24715  100    148   -0.0016   -0.0003     100.0  518.67  643.78  1596.01
# 24716  100    149    0.0034   -0.0003     100.0  518.67  643.29  1596.38
# 24717  100    150   -0.0016    0.0004     100.0  518.67  643.84  1604.53
# 24718  100    151   -0.0023    0.0004     100.0  518.67  643.94  1597.56
# 24719  100    152    0.0000    0.0003     100.0  518.67  643.64  1599.04
#
#             s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# 0      1396.84  14.62  ...  8145.32  8.4246  0.03  391  2388  100.0  39.11
# 1      1396.89  14.62  ...  8152.85  8.4403  0.03  392  2388  100.0  38.99
# 2      1405.61  14.62  ...  8150.17  8.3901  0.03  391  2388  100.0  38.85
# 3      1392.27  14.62  ...  8146.56  8.3878  0.03  392  2388  100.0  38.96
# 4      1397.65  14.62  ...  8147.80  8.3869  0.03  392  2388  100.0  39.14
# ...        ...    ...  ...      ...     ...   ...  ...   ...    ...    ...
# 24715  1424.11  14.62  ...  8138.08  8.5036  0.03  394  2388  100.0  38.44
# 24716  1429.14  14.62  ...  8144.36  8.5174  0.03  395  2388  100.0  38.50
# 24717  1431.41  14.62  ...  8135.95  8.5223  0.03  396  2388  100.0  38.39
# 24718  1426.57  14.62  ...  8141.24  8.5148  0.03  395  2388  100.0  38.31
# 24719  1436.06  14.62  ...  8136.98  8.5150  0.03  396  2388  100.0  38.56
#
#            s21  ttf  label_bc
# 0      23.3537  258         0
# 1      23.4491  257         0
# 2      23.3669  256         0
# 3      23.2951  255         0
# 4      23.4583  254         0
# ...        ...  ...       ...
# 24715  22.9631    4         1
# 24716  22.9746    3         1
# 24717  23.0682    2         1
# 24718  23.0753    1         1
# 24719  23.0847    0         1
#
# [24720 rows x 28 columns]

# %%
df_test
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0017   -0.0004     100.0  518.67  641.94  1581.93
# 1        1      2    0.0006   -0.0002     100.0  518.67  642.02  1584.86
# 2        1      3    0.0014   -0.0003     100.0  518.67  641.68  1581.78
# 3        1      4    0.0027    0.0001     100.0  518.67  642.20  1584.53
# 4        1      5   -0.0001    0.0001     100.0  518.67  642.46  1589.03
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 16591  100    243    0.0011   -0.0003     100.0  518.67  643.04  1594.99
# 16592  100    244   -0.0024    0.0002     100.0  518.67  642.47  1591.27
# 16593  100    245   -0.0053    0.0002     100.0  518.67  642.70  1593.81
# 16594  100    246   -0.0006    0.0001     100.0  518.67  642.19  1595.63
# 16595  100    247    0.0023    0.0004     100.0  518.67  643.19  1592.54
#
#             s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# 0      1396.93  14.62  ...  8133.48  8.3760  0.03  391  2388  100.0  39.07
# 1      1398.90  14.62  ...  8137.44  8.4062  0.03  391  2388  100.0  39.04
# 2      1391.92  14.62  ...  8138.25  8.3553  0.03  391  2388  100.0  39.10
# 3      1395.34  14.62  ...  8137.07  8.3709  0.03  392  2388  100.0  38.97
# 4      1395.86  14.62  ...  8134.20  8.4146  0.03  391  2388  100.0  39.09
# ...        ...    ...  ...      ...     ...   ...  ...   ...    ...    ...
# 16591  1411.28  14.62  ...  8162.24  8.2939  0.03  395  2388  100.0  39.40
# 16592  1417.64  14.62  ...  8163.24  8.3247  0.03  394  2388  100.0  39.42
# 16593  1412.70  14.62  ...  8162.12  8.3264  0.03  394  2388  100.0  39.43
# 16594  1406.58  14.62  ...  8164.20  8.2908  0.03  395  2388  100.0  39.40
# 16595  1407.20  14.62  ...  8169.24  8.3191  0.03  392  2388  100.0  39.41
#
#            s21  ttf  label_bc
# 0      23.4468  276         0
# 1      23.4807  275         0
# 2      23.4244  274         0
# 3      23.4782  273         0
# 4      23.3950  272         0
# ...        ...  ...       ...
# 16591  23.4949   32         0
# 16592  23.6011   31         0
# 16593  23.5482   30         1
# 16594  23.6687   29         1
# 16595  23.6536   28         1
#
# [16596 rows x 28 columns]

# %%
train_failure=df_train[df_train['label_bc']==0]
test_failure=df_test[df_test['label_bc']==0]

train_nonfail=df_train[df_train['label_bc']==1]
test_nonfail=df_test[df_test['label_bc']==1]

train_failure.shape,test_failure.shape,train_nonfail.shape,test_nonfail.shape
# Out:
# ((21620, 28), (16305, 28), (3100, 28), (291, 28))

# %%
train_failure=train_failure.sample(train_nonfail.shape[0],random_state=42)
train_failure.shape,train_nonfail.shape
# Out:
# ((3100, 28), (3100, 28))

# %%
test_failure=test_failure.sample(test_nonfail.shape[0],random_state=42)
test_failure.shape
# Out:
# (291, 28)

# %%
df_train=pd.concat([train_failure,train_nonfail],ignore_index=True)
df_train
# Out:
#        id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0       4     95   -0.0013    0.0003     100.0  518.67  642.49  1588.08
# 1      11     66   -0.0000    0.0002     100.0  518.67  641.92  1575.50
# 2      17    223    0.0028    0.0000     100.0  518.67  642.74  1587.83
# 3      55    341    0.0008   -0.0004     100.0  518.67  641.87  1580.56
# 4      94     61   -0.0011    0.0001     100.0  518.67  642.61  1588.05
# ...   ...    ...       ...       ...       ...     ...     ...      ...
# 6195  100    148   -0.0016   -0.0003     100.0  518.67  643.78  1596.01
# 6196  100    149    0.0034   -0.0003     100.0  518.67  643.29  1596.38
# 6197  100    150   -0.0016    0.0004     100.0  518.67  643.84  1604.53
# 6198  100    151   -0.0023    0.0004     100.0  518.67  643.94  1597.56
# 6199  100    152    0.0000    0.0003     100.0  518.67  643.64  1599.04
#
#            s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# 0     1408.55  14.62  ...  8124.72  8.4512  0.03  395  2388  100.0  38.86
# 1     1392.44  14.62  ...  8131.82  8.3584  0.03  390  2388  100.0  39.01
# 2     1394.02  14.62  ...  8139.49  8.3681  0.03  392  2388  100.0  39.14
# 3     1393.26  14.62  ...  8134.95  8.3681  0.03  391  2388  100.0  39.02
# 4     1400.24  14.62  ...  8145.06  8.3278  0.03  393  2388  100.0  39.38
# ...       ...    ...  ...      ...     ...   ...  ...   ...    ...    ...
# 6195  1424.11  14.62  ...  8138.08  8.5036  0.03  394  2388  100.0  38.44
# 6196  1429.14  14.62  ...  8144.36  8.5174  0.03  395  2388  100.0  38.50
# 6197  1431.41  14.62  ...  8135.95  8.5223  0.03  396  2388  100.0  38.39
# 6198  1426.57  14.62  ...  8141.24  8.5148  0.03  395  2388  100.0  38.31
# 6199  1436.06  14.62  ...  8136.98  8.5150  0.03  396  2388  100.0  38.56
#
#           s21  ttf  label_bc
# 0     23.2759  177         0
# 1     23.4670  131         0
# 2     23.4604   89         0
# 3     23.3001  184         0
# 4     23.5589  331         0
# ...       ...  ...       ...
# 6195  22.9631    4         1
# 6196  22.9746    3         1
# 6197  23.0682    2         1
# 6198  23.0753    1         1
# 6199  23.0847    0         1
#
# [6200 rows x 28 columns]

# %%
df_test=pd.concat([test_failure,test_nonfail],ignore_index=True)
df_test
# Out:
#       id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0     66     84    0.0004   -0.0004     100.0  518.67  642.67  1588.87
# 1     82     69   -0.0014    0.0004     100.0  518.67  641.64  1586.08
# 2     18    112    0.0025    0.0004     100.0  518.67  641.53  1588.95
# 3      8    109   -0.0010   -0.0005     100.0  518.67  643.02  1589.67
# 4     64    129   -0.0006    0.0005     100.0  518.67  641.86  1584.91
# ..   ...    ...       ...       ...       ...     ...     ...      ...
# 577   99    288    0.0007   -0.0002     100.0  518.67  643.26  1596.97
# 578   99    289    0.0013    0.0002     100.0  518.67  642.78  1597.57
# 579  100    245   -0.0053    0.0002     100.0  518.67  642.70  1593.81
# 580  100    246   -0.0006    0.0001     100.0  518.67  642.19  1595.63
# 581  100    247    0.0023    0.0004     100.0  518.67  643.19  1592.54
#
#           s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# 0    1412.82  14.62  ...  8133.03  8.4423  0.03  393  2388  100.0  38.79
# 1    1399.54  14.62  ...  8137.80  8.3802  0.03  392  2388  100.0  39.22
# 2    1392.73  14.62  ...  8134.85  8.3897  0.03  389  2388  100.0  39.08
# 3    1404.92  14.62  ...  8132.52  8.4319  0.03  393  2388  100.0  38.79
# 4    1391.70  14.62  ...  8133.14  8.4126  0.03  389  2388  100.0  38.97
# ..       ...    ...  ...      ...     ...   ...  ...   ...    ...    ...
# 577  1425.21  14.62  ...  8187.08  8.2162  0.03  394  2388  100.0  39.64
# 578  1419.47  14.62  ...  8185.00  8.2459  0.03  397  2388  100.0  39.59
# 579  1412.70  14.62  ...  8162.12  8.3264  0.03  394  2388  100.0  39.43
# 580  1406.58  14.62  ...  8164.20  8.2908  0.03  395  2388  100.0  39.40
# 581  1407.20  14.62  ...  8169.24  8.3191  0.03  392  2388  100.0  39.41
#
#          s21  ttf  label_bc
# 0    23.2812  125         0
# 1    23.4764  131         0
# 2    23.3152  264         0
# 3    23.2346  138         0
# 4    23.3823  170         0
# ..       ...  ...       ...
# 577  23.6941    9         1
# 578  23.7059    8         1
# 579  23.5482   30         1
# 580  23.6687   29         1
# 581  23.6536   28         1
#
# [582 rows x 28 columns]

# %%
df_train['label_bc'].value_counts()
# Out:
# 0    3100
# 1    3100
# Name: label_bc, dtype: int64

# %%
df_test['label_bc'].value_counts()
# Out:
# 0    291
# 1    291
# Name: label_bc, dtype: int64

# %%
X_train=df_train.drop('label_bc',axis=1)
y_train=df_train['label_bc']
X_train,y_train
# Out:
# (       id  cycle  setting1  setting2  setting3      s1      s2       s3  \
#  0       4     95   -0.0013    0.0003     100.0  518.67  642.49  1588.08
#  1      11     66   -0.0000    0.0002     100.0  518.67  641.92  1575.50
#  2      17    223    0.0028    0.0000     100.0  518.67  642.74  1587.83
#  3      55    341    0.0008   -0.0004     100.0  518.67  641.87  1580.56
#  4      94     61   -0.0011    0.0001     100.0  518.67  642.61  1588.05
#  ...   ...    ...       ...       ...       ...     ...     ...      ...
#  6195  100    148   -0.0016   -0.0003     100.0  518.67  643.78  1596.01
#  6196  100    149    0.0034   -0.0003     100.0  518.67  643.29  1596.38
#  6197  100    150   -0.0016    0.0004     100.0  518.67  643.84  1604.53
#  6198  100    151   -0.0023    0.0004     100.0  518.67  643.94  1597.56
#  6199  100    152    0.0000    0.0003     100.0  518.67  643.64  1599.04
#
#             s4     s5  ...      s13      s14     s15   s16  s17   s18    s19  \
#  0     1408.55  14.62  ...  2388.12  8124.72  8.4512  0.03  395  2388  100.0
#  1     1392.44  14.62  ...  2387.93  8131.82  8.3584  0.03  390  2388  100.0
#  2     1394.02  14.62  ...  2388.03  8139.49  8.3681  0.03  392  2388  100.0
#  3     1393.26  14.62  ...  2387.91  8134.95  8.3681  0.03  391  2388  100.0
#  4     1400.24  14.62  ...  2388.08  8145.06  8.3278  0.03  393  2388  100.0
#  ...       ...    ...  ...      ...      ...     ...   ...  ...   ...    ...
#  6195  1424.11  14.62  ...  2388.30  8138.08  8.5036  0.03  394  2388  100.0
#  6196  1429.14  14.62  ...  2388.28  8144.36  8.5174  0.03  395  2388  100.0
#  6197  1431.41  14.62  ...  2388.24  8135.95  8.5223  0.03  396  2388  100.0
#  6198  1426.57  14.62  ...  2388.26  8141.24  8.5148  0.03  395  2388  100.0
#  6199  1436.06  14.62  ...  2388.24  8136.98  8.5150  0.03  396  2388  100.0
#
#          s20      s21  ttf
#  0     38.86  23.2759  177
#  1     39.01  23.4670  131
#  2     39.14  23.4604   89
#  3     39.02  23.3001  184
#  4     39.38  23.5589  331
#  ...     ...      ...  ...
#  6195  38.44  22.9631    4
#  6196  38.50  22.9746    3
#  6197  38.39  23.0682    2
#  6198  38.31  23.0753    1
#  6199  38.56  23.0847    0
#
#  [6200 rows x 27 columns],
#  0       0
#  1       0
#  2       0
#  3       0
#  4       0
#         ..
#  6195    1
#  6196    1
#  6197    1
#  6198    1
#  6199    1
#  Name: label_bc, Length: 6200, dtype: int64)

# %%
X_test=df_test.drop('label_bc',axis=1)
y_test=df_test['label_bc']

# %%
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)
X_train.shape,X_test.shape
# Out:
# ((6200, 27, 1), (582, 27, 1))

# %%
epochs=20
model=Sequential()
model.add(Dense(16,activation='relu',input_shape=X_train[0].shape))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(8,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(4,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))


model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 27, 16)            32
#
#  batch_normalization (BatchN  (None, 27, 16)           64
#  ormalization)
#
#  dropout (Dropout)           (None, 27, 16)            0
#
#  dense_1 (Dense)             (None, 27, 8)             136
#
#  batch_normalization_1 (Batc  (None, 27, 8)            32
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 27, 8)             0
#
#  flatten (Flatten)           (None, 216)               0
#
#  dense_2 (Dense)             (None, 4)                 868
#
#  batch_normalization_2 (Batc  (None, 4)                16
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 4)                 0
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 1,153
# Trainable params: 1,097
# Non-trainable params: 56
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train ,epochs=epochs,validation_data=(X_test,y_test),verbose=1,batch_size=32)
# Out:
# Epoch 1/20
# 194/194 [==============================] - 3s 7ms/step - loss: 0.3667 - accuracy: 0.8556 - val_loss: 0.6628 - val_accuracy: 0.5189
# Epoch 2/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.2108 - accuracy: 0.9287 - val_loss: 0.4236 - val_accuracy: 0.7629
# Epoch 3/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1813 - accuracy: 0.9335 - val_loss: 0.2358 - val_accuracy: 0.8969
# Epoch 4/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1551 - accuracy: 0.9427 - val_loss: 0.0883 - val_accuracy: 0.9622
# Epoch 5/20
# 194/194 [==============================] - 1s 3ms/step - loss: 0.1605 - accuracy: 0.9405 - val_loss: 0.0901 - val_accuracy: 0.9605
# Epoch 6/20
# 194/194 [==============================] - 1s 3ms/step - loss: 0.1506 - accuracy: 0.9435 - val_loss: 0.0962 - val_accuracy: 0.9605
# Epoch 7/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1416 - accuracy: 0.9468 - val_loss: 0.0808 - val_accuracy: 0.9588
# Epoch 8/20
# 194/194 [==============================] - 1s 3ms/step - loss: 0.1487 - accuracy: 0.9479 - val_loss: 0.0831 - val_accuracy: 0.9639
# Epoch 9/20
# 194/194 [==============================] - 1s 3ms/step - loss: 0.1463 - accuracy: 0.9423 - val_loss: 0.0764 - val_accuracy: 0.9691
# Epoch 10/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1373 - accuracy: 0.9487 - val_loss: 0.1727 - val_accuracy: 0.9244
# Epoch 11/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1439 - accuracy: 0.9448 - val_loss: 0.2629 - val_accuracy: 0.8900
# Epoch 12/20
# 194/194 [==============================] - 1s 3ms/step - loss: 0.1457 - accuracy: 0.9453 - val_loss: 0.1489 - val_accuracy: 0.9330
# Epoch 13/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1471 - accuracy: 0.9444 - val_loss: 0.1732 - val_accuracy: 0.9192
# Epoch 14/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1374 - accuracy: 0.9473 - val_loss: 0.1136 - val_accuracy: 0.9485
# Epoch 15/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1367 - accuracy: 0.9469 - val_loss: 0.1724 - val_accuracy: 0.9210
# Epoch 16/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1329 - accuracy: 0.9476 - val_loss: 0.0694 - val_accuracy: 0.9777
# Epoch 17/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1375 - accuracy: 0.9494 - val_loss: 0.0765 - val_accuracy: 0.9674
# Epoch 18/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1359 - accuracy: 0.9473 - val_loss: 0.1002 - val_accuracy: 0.9622
# Epoch 19/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1349 - accuracy: 0.9497 - val_loss: 0.1128 - val_accuracy: 0.9570
# Epoch 20/20
# 194/194 [==============================] - 1s 4ms/step - loss: 0.1348 - accuracy: 0.9513 - val_loss: 0.0754 - val_accuracy: 0.9708

# %%
acc=model.evaluate(X_train,y_train)
print("Accuracy=",acc[1])
# Out:
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9627
# Accuracy= 0.9627419114112854

# %%
def plot_lc(history,epochs):
    epoch_range=range(1,epochs+1)
    plt.plot(epoch_range,history.history['accuracy'])
    plt.plot(epoch_range,history.history['val_accuracy'])
    plt.title("model accuracy")
    plt.xlabel("epochs")
    plt.ylabel("accuracy")
    plt.legend(["train","val"],loc='upper left')
    plt.show()
    
    
   
    plt.plot(epoch_range,history.history['loss'])
    plt.plot(epoch_range,history.history['val_loss'])
    plt.title("model loss")
    plt.xlabel("epochs")
    plt.ylabel("loss")
    plt.legend(["train","val"],loc='upper left')
    plt.show()

# %%
plot_lc(history,epochs)

# %%
y_pred=(model.predict(X_test)>0.5).astype("int32")
print('Accuracy of model on test data: ',accuracy_score(y_test,y_pred))
print('Confusion Matrix: \n',confusion_matrix(y_test,y_pred))
# Out:
# 19/19 [==============================] - 0s 1ms/step
# Accuracy of model on test data:  0.9707903780068728
# Confusion Matrix:
#  [[289   2]
#  [ 15 276]]
